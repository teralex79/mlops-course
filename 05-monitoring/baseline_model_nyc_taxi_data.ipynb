# %% [markdown]
# # Baseline model for batch monitoring example

# %%
import requests
import datetime
import pandas as pd

from tqdm import tqdm

# %%
files = [('green_tripdata_2024-04.parquet', './data')]

print("Download files:")
for file, path in files:
    url=f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
    resp=requests.get(url, stream=True)
    save_path=f"{path}/{file}"
    with open(save_path, "wb") as handle:
        for data in tqdm(resp.iter_content(),
                        desc=f"{file}",
                        postfix=f"save to {save_path}",
                        total=int(resp.headers["Content-Length"])):
            handle.write(data)
# Out:
# Download files:
# green_tripdata_2024-04.parquet: 100%|█████████████| 1346502/1346502 [00:06<00:00, 199125.86it/s, save to ./data/green_tripdata_2024-04.parquet]

# %%
march_data = pd.read_parquet('data/green_tripdata_2024-04.parquet')

# %%
march_data.describe()
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  56471.000000                       56471                       56471
# mean       1.883976  2024-04-15 22:33:04.951019  2024-04-15 22:51:29.480034
# min        1.000000         2024-03-31 22:34:23         2024-03-31 22:45:33
# 25%        2.000000         2024-04-08 11:57:07  2024-04-08 12:12:35.500000
# 50%        2.000000         2024-04-16 01:54:42         2024-04-16 02:16:54
# 75%        2.000000  2024-04-23 13:20:03.500000         2024-04-23 13:38:45
# max        2.000000         2024-04-30 23:59:33         2024-05-01 23:35:25
# std        0.320257                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  54483.000000  56471.000000  56471.000000     54483.000000
# mean       1.186297     96.040428    141.340688         1.304958
# min        1.000000      1.000000      1.000000         0.000000
# 25%        1.000000     74.000000     74.000000         1.000000
# 50%        1.000000     75.000000    140.000000         1.000000
# 75%        1.000000     97.000000    226.000000         1.000000
# max       99.000000    265.000000    265.000000         9.000000
# std        1.431596     57.045495     76.511064         0.951083
#
#        trip_distance   fare_amount         extra       mta_tax    tip_amount  \
# count   56471.000000  56471.000000  56471.000000  56471.000000  56471.000000
# mean       12.088796     17.522481      0.931872      0.571665      2.518530
# min         0.000000   -450.000000     -5.000000     -0.500000    -17.880000
# 25%         1.100000      9.300000      0.000000      0.500000      0.000000
# 50%         1.820000     13.500000      0.000000      0.500000      2.020000
# 75%         3.130000     20.500000      2.500000      0.500000      3.780000
# max    192842.370000    578.400000      7.500000      1.500000    343.240000
# std       948.127785     15.166440      1.392809      0.358631      3.399307
#
#        tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# count  56471.000000        0.0           56471.000000  56471.000000
# mean       0.211510        NaN               0.979559     23.363727
# min        0.000000        NaN              -1.000000   -451.000000
# 25%        0.000000        NaN               1.000000     13.800000
# 50%        0.000000        NaN               1.000000     19.000000
# 75%        0.000000        NaN               1.000000     27.600000
# max       35.000000        NaN               1.000000    579.900000
# std        1.270576        NaN               0.156320     17.329174
#
#        payment_type     trip_type  congestion_surcharge
# count  54483.000000  54475.000000          54483.000000
# mean       1.296661      1.038440              0.815314
# min        1.000000      1.000000             -2.750000
# 25%        1.000000      1.000000              0.000000
# 50%        1.000000      1.000000              0.000000
# 75%        2.000000      1.000000              2.750000
# max        4.000000      2.000000              2.750000
# std        0.488103      0.192257              1.255446

# %%
march_data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 march_data.shape()
#
# TypeError: 'tuple' object is not callable
